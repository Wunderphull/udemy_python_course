# %%
import numpy as np

import pandas as pd

# Using from pandas import Series,Dataframe allows us to more easily use them.
# With this we can use pd instead of pd.Series or pd.DataFrame.

from pandas import Series,DataFrame

# %%
# Lets get some data to make a dataframe.

# %%
import webbrowser

website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'

webbrowser.open(website)
# Out:
# True

# %%
# Copy and read data using pandas in order to grab a dataframe.

# %%
# I have gone to the website link, and copied the first five rows of the spreadsheet to the clipboard.
# I can copy and read data from my clipboard.

nfl_frame = pd.read_clipboard()

nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North

# %%
# Grab column names:

nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame['First NFL season']
# Out:
# 0    1960
# 1    1921
# 2    1996
# 3    1960
# 4    1920
# Name: First NFL season, dtype: int64

# %%
# Grab multiple columns:

DataFrame(nfl_frame,columns=['Team','First NFL season','GP'])
# Out:
#                    Team  First NFL season     GP
# 0        Dallas Cowboys              1960    964
# 1     Green Bay Packers              1921  1,418
# 2      Baltimore Ravens              1996    434
# 3  New England Patriots              1960    966
# 4         Chicago Bears              1920  1,452

# %%
# Ask for a column that does not exist:

DataFrame(nfl_frame,columns=['Team','First NFL season','GP','Stadium'])

# Instead of returning an error, it fills the column with 'null' values.
# Out:
#                    Team  First NFL season     GP  Stadium
# 0        Dallas Cowboys              1960    964      NaN
# 1     Green Bay Packers              1921  1,418      NaN
# 2      Baltimore Ravens              1996    434      NaN
# 3  New England Patriots              1960    966      NaN
# 4         Chicago Bears              1920  1,452      NaN

# %%
# See the first (n) rows:

nfl_frame.head(3)
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL season  \
# 0     1     Dallas Cowboys    964  550   408     6  0.574              1960
# 1     2  Green Bay Packers  1,418  790   590    38  0.571              1921
# 2     3   Baltimore Ravens    434  243   190     1  0.561              1996
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  AFC North

# %%
# See the last (n) rows:

nfl_frame.tail(3)
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division       Stadiums
# 2              1996  AFC North            NaN
# 3              1960   AFC East  King's Stands
# 4              1920  NFC North      Greatbowl

# %%
# .loc description: https://www.codecademy.com/resources/docs/pandas/dataframe/loc

nfl_frame.loc[3]
# Out:
# Rank                                   4
# Team                New England Patriots
# GP                                   966
# Won                                  537
# Lost                                 420
# Tied                                   9
# Pct.                               0.561
# First NFL season                    1960
# Division                        AFC East
# Stadiums                   King's Stands
# Name: 3, dtype: object

# %%
# Assign values to entire columns.

nfl_frame['Stadium'] = "Levi's Stadium"

nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division        Stadiums         Stadium
# 0              1960   NFC East  Levi's Stadium  Levi's Stadium
# 1              1921  NFC North             NaN  Levi's Stadium
# 2              1996  AFC North             NaN  Levi's Stadium
# 3              1960   AFC East   King's Stands  Levi's Stadium
# 4              1920  NFC North       Greatbowl  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division        Stadiums  Stadium
# 0              1960   NFC East  Levi's Stadium        0
# 1              1921  NFC North             NaN        1
# 2              1996  AFC North             NaN        2
# 3              1960   AFC East   King's Stands        3
# 4              1920  NFC North       Greatbowl        4

# %%
stadiums = Series(["Levi's Stadium","King's Stands",'Greatbowl'],index=[0,3,4])

# %%
# Insert into our dataframe:

nfl_frame['Stadiums'] = stadiums

nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division        Stadiums  Stadium
# 0              1960   NFC East  Levi's Stadium        0
# 1              1921  NFC North             NaN        1
# 2              1996  AFC North             NaN        2
# 3              1960   AFC East   King's Stands        3
# 4              1920  NFC North       Greatbowl        4

# %%
# Delete a column

del nfl_frame['Stadium']

nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division        Stadiums
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North             NaN
# 2              1996  AFC North             NaN
# 3              1960   AFC East   King's Stands
# 4              1920  NFC North       Greatbowl

# %%
# Pandas can automatically take up a dictionary, as long as lists match up concerning number of datapoints.

data = {'City':['SF','LA','NYC'],'Population':[837000,3880000,8400000]}

city_frame = DataFrame(data)

city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
#For full list of ways to create DataFrames from various sources go to teh documentation for pandas:

website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'

webbrowser.open(website)
# Out:
# True
